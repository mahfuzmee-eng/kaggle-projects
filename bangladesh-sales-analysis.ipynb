# %% [markdown]
# <a href="https://colab.research.google.com/github/mahfuzmee-eng/kaggle-projects/blob/main/bangladesh-sales-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0a72bfc5-202f-4fe7-9c86-76002583501f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a72bfc5-202f-4fe7-9c86-76002583501f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d mdmahfuzsumon/sales-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mdmahfuzsumon/sales-dataset
# License(s): MIT
# ...
#   0% 0.00/4.83k [00:00<?, ?B/s]
# 100% 4.83k/4.83k [00:00<00:00, 16.9MB/s]

# %%
# !unzip sales-dataset.zip
# Out:
# Archive:  sales-dataset.zip
#   inflating: sample_sales_dataset.xlsx

# %%
import pandas as pd

df = pd.read_excel("sample_sales_dataset.xlsx")
df.head()
# Out:
#    Order_ID  Order_Date      Region       Product         Category  Sales  \
# 0      1001  2024-01-05       Dhaka  Office Chair        Furniture  12000
# 1      1002  2024-01-06  Chittagong        Laptop       Technology  55000
# 2      1003  2024-01-07      Khulna      Pen Pack  Office Supplies    500
# 3      1004  2024-01-08      Sylhet          Desk        Furniture   8000
# 4      1005  2024-01-09    Rajshahi       Printer       Technology  15000
#
#    Quantity  Profit
# 0         2    2000
# 1         1    5000
# 2        10     120
# 3         1    1500
# 4         1    2500

# %%
df["Sales"].sum()
# Out:
# np.int64(108800)

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# Barisal       18000
# Chittagong    55000
# Dhaka         12300
# Khulna          500
# Rajshahi      15000
# Sylhet         8000
# Name: Sales, dtype: int64

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          20000
# Office Supplies      800
# Technology         88000
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt

df.groupby("Region")["Sales"].sum().plot(kind="bar")
plt.title("Sales by Region")
plt.show()
